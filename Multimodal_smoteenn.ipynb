# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.losses import MeanSquaredError

# Instantiate the Mean Squared Error loss
mse = MeanSquaredError()
from tensorflow.keras.metrics import MeanSquaredError
import matplotlib.pyplot as plt

def create_multimodal_autoencoder(packet_input_size, temporal_input_size, protocol_input_size):
    # Define input layers for each modality
    packet_input = Input(shape=(packet_input_size,), name="packet_input")
    temporal_input = Input(shape=(temporal_input_size,), name="temporal_input")
    protocol_input = Input(shape=(protocol_input_size,), name="protocol_input")

    # Packet encoder
    packet_encoded = Dense(64, activation='relu')(packet_input)
    packet_encoded = Dense(32, activation='relu')(packet_encoded)

    # Temporal encoder
    temporal_encoded = Dense(64, activation='relu')(temporal_input)
    temporal_encoded = Dense(32, activation='relu')(temporal_encoded)

    # Protocol encoder
    protocol_encoded = Dense(16, activation='relu')(protocol_input)
    protocol_encoded = Dense(8, activation='relu')(protocol_encoded)

    # Combine the encoded representations
    combined = Concatenate()([packet_encoded, temporal_encoded, protocol_encoded])

    # Shared latent space
    latent = Dense(32, activation='relu', name="latent_space")(combined)

    # Decoders for each modality
    # Packet decoder
    packet_decoded = Dense(32, activation='relu')(latent)
    packet_decoded = Dense(64, activation='relu')(packet_decoded)
    packet_decoded = Dense(packet_input_size, activation='linear', name="packet_output")(packet_decoded)

    # Temporal decoder
    temporal_decoded = Dense(32, activation='relu')(latent)
    temporal_decoded = Dense(64, activation='relu')(temporal_decoded)
    temporal_decoded = Dense(temporal_input_size, activation='linear', name="temporal_output")(temporal_decoded)

    # Protocol decoder
    protocol_decoded = Dense(8, activation='relu')(latent)
    protocol_decoded = Dense(16, activation='relu')(protocol_decoded)
    protocol_decoded = Dense(protocol_input_size, activation='linear', name="protocol_output")(protocol_decoded)

    # Build the autoencoder model
    autoencoder = Model(
        inputs=[packet_input, temporal_input, protocol_input], 
        outputs=[packet_decoded, temporal_decoded, protocol_decoded]
    )

    # Compile the model
    autoencoder.compile(
        optimizer='adam', 
        loss={
            'packet_output': 'mean_squared_error', 
            'temporal_output': 'mean_squared_error', 
            'protocol_output': 'mean_squared_error'
        }
    )

    return autoencoder

def train_multimodal_autoencoder(data_path):
    # Load the dataset
    data = pd.read_csv(data_path)

    # Define feature groups
    packet_features = ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size']

   
    temporal_features = ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur']

    protocol_features = ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']

    # Separate features
    X_packet = data[packet_features]
    X_temporal = data[temporal_features]
    X_protocol = data[protocol_features]

    # Normalize features
    scaler_packet = StandardScaler()
    scaler_temporal = StandardScaler()
    scaler_protocol = StandardScaler()

    X_packet_scaled = scaler_packet.fit_transform(X_packet)
    X_temporal_scaled = scaler_temporal.fit_transform(X_temporal)
    X_protocol_scaled = scaler_protocol.fit_transform(X_protocol)

    # Create and train the autoencoder
    autoencoder = create_multimodal_autoencoder(
        len(packet_features), 
        len(temporal_features), 
        len(protocol_features)
    )

    # Train the autoencoder
    history = autoencoder.fit(
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        epochs=50, 
        batch_size=32, 
        validation_split=0.2,
        verbose=1
    )

    # Save the model and scalers
    autoencoder.save("multimodal_smoteenn_autoencoder.h5", save_format='h5')
    import joblib
    joblib.dump(scaler_packet, 'packet_scaler.pkl')
    joblib.dump(scaler_temporal, 'temporal_scaler.pkl')
    joblib.dump(scaler_protocol, 'protocol_scaler.pkl')

    # Plot the training and validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Multimodal Autoencoder Training and Validation Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()
    plt.close()

    print("Model training completed. Model and scalers saved.")

# Example usage
if __name__ == "__main__":
    train_multimodal_autoencoder('balanced_smoteenn.csv')
# Out:
# Epoch 1/50
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 2.9465 - packet_output_loss: 0.8307 - protocol_output_loss: 1.0160 - temporal_output_loss: 1.0974 - val_loss: 1.8649 - val_packet_output_loss: 0.6495 - val_protocol_output_loss: 0.8162 - val_temporal_output_loss: 0.3010
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7901 - packet_output_loss: 0.5141 - protocol_output_loss: 0.7937 - temporal_output_loss: 0.4829 - val_loss: 1.2250 - val_packet_output_loss: 0.2869 - val_protocol_output_loss: 0.7995 - val_temporal_output_loss: 0.0975
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3556 - packet_output_loss: 0.5305 - protocol_output_loss: 0.6689 - temporal_output_loss: 0.1551 - val_loss: 1.0290 - val_packet_output_loss: 0.1301 - val_protocol_output_loss: 0.8057 - val_temporal_output_loss: 0.0642
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8051 - packet_output_loss: 0.1511 - protocol_output_loss: 0.5972 - temporal_output_loss: 0.0564 - val_loss: 0.9640 - val_packet_output_loss: 0.1230 - val_protocol_output_loss: 0.7646 - val_temporal_output_loss: 0.0473
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6446 - packet_output_loss: 0.1186 - protocol_output_loss: 0.4897 - temporal_output_loss: 0.0362 - val_loss: 0.8937 - val_packet_output_loss: 0.1033 - val_protocol_output_loss: 0.7193 - val_temporal_output_loss: 0.0426
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5527 - packet_output_loss: 0.0910 - protocol_output_loss: 0.4323 - temporal_output_loss: 0.0288 - val_loss: 0.8541 - val_packet_output_loss: 0.0941 - val_protocol_output_loss: 0.6931 - val_temporal_output_loss: 0.0389
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4816 - packet_output_loss: 0.0898 - protocol_output_loss: 0.3528 - temporal_output_loss: 0.0387 - val_loss: 0.8233 - val_packet_output_loss: 0.0777 - val_protocol_output_loss: 0.6765 - val_temporal_output_loss: 0.0416
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4738 - packet_output_loss: 0.1045 - protocol_output_loss: 0.3383 - temporal_output_loss: 0.0318 - val_loss: 0.7937 - val_packet_output_loss: 0.0668 - val_protocol_output_loss: 0.6649 - val_temporal_output_loss: 0.0345
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3607 - packet_output_loss: 0.0464 - protocol_output_loss: 0.2894 - temporal_output_loss: 0.0251 - val_loss: 0.7562 - val_packet_output_loss: 0.0601 - val_protocol_output_loss: 0.6355 - val_temporal_output_loss: 0.0348
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3364 - packet_output_loss: 0.0517 - protocol_output_loss: 0.2647 - temporal_output_loss: 0.0199 - val_loss: 0.7536 - val_packet_output_loss: 0.0553 - val_protocol_output_loss: 0.6314 - val_temporal_output_loss: 0.0414
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3225 - packet_output_loss: 0.0322 - protocol_output_loss: 0.2653 - temporal_output_loss: 0.0250 - val_loss: 0.7193 - val_packet_output_loss: 0.0557 - val_protocol_output_loss: 0.6036 - val_temporal_output_loss: 0.0357
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2792 - packet_output_loss: 0.0335 - protocol_output_loss: 0.2280 - temporal_output_loss: 0.0175 - val_loss: 0.7046 - val_packet_output_loss: 0.0541 - val_protocol_output_loss: 0.5930 - val_temporal_output_loss: 0.0331
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2744 - packet_output_loss: 0.0449 - protocol_output_loss: 0.2108 - temporal_output_loss: 0.0189 - val_loss: 0.6620 - val_packet_output_loss: 0.0483 - val_protocol_output_loss: 0.5597 - val_temporal_output_loss: 0.0316
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2447 - packet_output_loss: 0.0355 - protocol_output_loss: 0.1943 - temporal_output_loss: 0.0150 - val_loss: 0.6477 - val_packet_output_loss: 0.0457 - val_protocol_output_loss: 0.5479 - val_temporal_output_loss: 0.0321
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2614 - packet_output_loss: 0.0601 - protocol_output_loss: 0.1853 - temporal_output_loss: 0.0158 - val_loss: 0.6032 - val_packet_output_loss: 0.0446 - val_protocol_output_loss: 0.5093 - val_temporal_output_loss: 0.0291
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2144 - packet_output_loss: 0.0220 - protocol_output_loss: 0.1794 - temporal_output_loss: 0.0130 - val_loss: 0.6112 - val_packet_output_loss: 0.0568 - val_protocol_output_loss: 0.4965 - val_temporal_output_loss: 0.0356
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1953 - packet_output_loss: 0.0279 - protocol_output_loss: 0.1514 - temporal_output_loss: 0.0158 - val_loss: 0.5482 - val_packet_output_loss: 0.0464 - val_protocol_output_loss: 0.4531 - val_temporal_output_loss: 0.0305
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1830 - packet_output_loss: 0.0249 - protocol_output_loss: 0.1470 - temporal_output_loss: 0.0110 - val_loss: 0.5462 - val_packet_output_loss: 0.0455 - val_protocol_output_loss: 0.4514 - val_temporal_output_loss: 0.0297
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1773 - packet_output_loss: 0.0245 - protocol_output_loss: 0.1432 - temporal_output_loss: 0.0099 - val_loss: 0.5114 - val_packet_output_loss: 0.0434 - val_protocol_output_loss: 0.4215 - val_temporal_output_loss: 0.0283
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1606 - packet_output_loss: 0.0178 - protocol_output_loss: 0.1332 - temporal_output_loss: 0.0097 - val_loss: 0.5032 - val_packet_output_loss: 0.0413 - val_protocol_output_loss: 0.4164 - val_temporal_output_loss: 0.0262
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1717 - packet_output_loss: 0.0257 - protocol_output_loss: 0.1367 - temporal_output_loss: 0.0091 - val_loss: 0.5002 - val_packet_output_loss: 0.0400 - val_protocol_output_loss: 0.4129 - val_temporal_output_loss: 0.0273
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1583 - packet_output_loss: 0.0162 - protocol_output_loss: 0.1337 - temporal_output_loss: 0.0085 - val_loss: 0.4716 - val_packet_output_loss: 0.0408 - val_protocol_output_loss: 0.3850 - val_temporal_output_loss: 0.0275
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1443 - packet_output_loss: 0.0172 - protocol_output_loss: 0.1180 - temporal_output_loss: 0.0091 - val_loss: 0.4526 - val_packet_output_loss: 0.0409 - val_protocol_output_loss: 0.3666 - val_temporal_output_loss: 0.0268
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1342 - packet_output_loss: 0.0142 - protocol_output_loss: 0.1105 - temporal_output_loss: 0.0093 - val_loss: 0.4580 - val_packet_output_loss: 0.0381 - val_protocol_output_loss: 0.3722 - val_temporal_output_loss: 0.0278
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1211 - packet_output_loss: 0.0143 - protocol_output_loss: 0.1002 - temporal_output_loss: 0.0069 - val_loss: 0.4349 - val_packet_output_loss: 0.0382 - val_protocol_output_loss: 0.3511 - val_temporal_output_loss: 0.0269
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1265 - packet_output_loss: 0.0160 - protocol_output_loss: 0.1038 - temporal_output_loss: 0.0068 - val_loss: 0.4306 - val_packet_output_loss: 0.0343 - val_protocol_output_loss: 0.3494 - val_temporal_output_loss: 0.0274
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1179 - packet_output_loss: 0.0153 - protocol_output_loss: 0.0961 - temporal_output_loss: 0.0064 - val_loss: 0.4302 - val_packet_output_loss: 0.0412 - val_protocol_output_loss: 0.3423 - val_temporal_output_loss: 0.0268
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1139 - packet_output_loss: 0.0170 - protocol_output_loss: 0.0899 - temporal_output_loss: 0.0070 - val_loss: 0.4233 - val_packet_output_loss: 0.0382 - val_protocol_output_loss: 0.3356 - val_temporal_output_loss: 0.0283
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1226 - packet_output_loss: 0.0231 - protocol_output_loss: 0.0924 - temporal_output_loss: 0.0071 - val_loss: 0.4141 - val_packet_output_loss: 0.0348 - val_protocol_output_loss: 0.3312 - val_temporal_output_loss: 0.0263
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1289 - packet_output_loss: 0.0304 - protocol_output_loss: 0.0817 - temporal_output_loss: 0.0168 - val_loss: 0.4017 - val_packet_output_loss: 0.0368 - val_protocol_output_loss: 0.3145 - val_temporal_output_loss: 0.0286
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0885 - packet_output_loss: 0.0116 - protocol_output_loss: 0.0714 - temporal_output_loss: 0.0057 - val_loss: 0.3946 - val_packet_output_loss: 0.0356 - val_protocol_output_loss: 0.3090 - val_temporal_output_loss: 0.0280
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0929 - packet_output_loss: 0.0122 - protocol_output_loss: 0.0738 - temporal_output_loss: 0.0067 - val_loss: 0.3771 - val_packet_output_loss: 0.0336 - val_protocol_output_loss: 0.2963 - val_temporal_output_loss: 0.0254
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0821 - packet_output_loss: 0.0087 - protocol_output_loss: 0.0681 - temporal_output_loss: 0.0054 - val_loss: 0.3835 - val_packet_output_loss: 0.0306 - val_protocol_output_loss: 0.3042 - val_temporal_output_loss: 0.0255
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0876 - packet_output_loss: 0.0095 - protocol_output_loss: 0.0730 - temporal_output_loss: 0.0053 - val_loss: 0.3785 - val_packet_output_loss: 0.0320 - val_protocol_output_loss: 0.2961 - val_temporal_output_loss: 0.0273
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0739 - packet_output_loss: 0.0084 - protocol_output_loss: 0.0602 - temporal_output_loss: 0.0052 - val_loss: 0.3606 - val_packet_output_loss: 0.0308 - val_protocol_output_loss: 0.2824 - val_temporal_output_loss: 0.0247
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0680 - packet_output_loss: 0.0084 - protocol_output_loss: 0.0543 - temporal_output_loss: 0.0052 - val_loss: 0.3565 - val_packet_output_loss: 0.0310 - val_protocol_output_loss: 0.2765 - val_temporal_output_loss: 0.0258
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0636 - packet_output_loss: 0.0086 - protocol_output_loss: 0.0505 - temporal_output_loss: 0.0044 - val_loss: 0.3486 - val_packet_output_loss: 0.0305 - val_protocol_output_loss: 0.2703 - val_temporal_output_loss: 0.0252
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0660 - packet_output_loss: 0.0078 - protocol_output_loss: 0.0534 - temporal_output_loss: 0.0048 - val_loss: 0.3565 - val_packet_output_loss: 0.0359 - val_protocol_output_loss: 0.2714 - val_temporal_output_loss: 0.0248
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0706 - packet_output_loss: 0.0143 - protocol_output_loss: 0.0501 - temporal_output_loss: 0.0062 - val_loss: 0.3528 - val_packet_output_loss: 0.0299 - val_protocol_output_loss: 0.2725 - val_temporal_output_loss: 0.0262
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0628 - packet_output_loss: 0.0105 - protocol_output_loss: 0.0470 - temporal_output_loss: 0.0052 - val_loss: 0.3443 - val_packet_output_loss: 0.0306 - val_protocol_output_loss: 0.2636 - val_temporal_output_loss: 0.0262
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0616 - packet_output_loss: 0.0088 - protocol_output_loss: 0.0481 - temporal_output_loss: 0.0047 - val_loss: 0.3418 - val_packet_output_loss: 0.0293 - val_protocol_output_loss: 0.2597 - val_temporal_output_loss: 0.0282
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673 - packet_output_loss: 0.0102 - protocol_output_loss: 0.0463 - temporal_output_loss: 0.0107 - val_loss: 0.3457 - val_packet_output_loss: 0.0293 - val_protocol_output_loss: 0.2650 - val_temporal_output_loss: 0.0263
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0691 - packet_output_loss: 0.0147 - protocol_output_loss: 0.0455 - temporal_output_loss: 0.0088 - val_loss: 0.3325 - val_packet_output_loss: 0.0301 - val_protocol_output_loss: 0.2540 - val_temporal_output_loss: 0.0243
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0729 - packet_output_loss: 0.0201 - protocol_output_loss: 0.0439 - temporal_output_loss: 0.0089 - val_loss: 0.3300 - val_packet_output_loss: 0.0281 - val_protocol_output_loss: 0.2542 - val_temporal_output_loss: 0.0236
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0714 - packet_output_loss: 0.0224 - protocol_output_loss: 0.0419 - temporal_output_loss: 0.0072 - val_loss: 0.3258 - val_packet_output_loss: 0.0317 - val_protocol_output_loss: 0.2467 - val_temporal_output_loss: 0.0234
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0628 - packet_output_loss: 0.0143 - protocol_output_loss: 0.0416 - temporal_output_loss: 0.0068 - val_loss: 0.3311 - val_packet_output_loss: 0.0322 - val_protocol_output_loss: 0.2496 - val_temporal_output_loss: 0.0249
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0839 - packet_output_loss: 0.0357 - protocol_output_loss: 0.0400 - temporal_output_loss: 0.0084 - val_loss: 0.3185 - val_packet_output_loss: 0.0284 - val_protocol_output_loss: 0.2413 - val_temporal_output_loss: 0.0246
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0531 - packet_output_loss: 0.0109 - protocol_output_loss: 0.0370 - temporal_output_loss: 0.0052 - val_loss: 0.3172 - val_packet_output_loss: 0.0301 - val_protocol_output_loss: 0.2389 - val_temporal_output_loss: 0.0239
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588 - packet_output_loss: 0.0208 - protocol_output_loss: 0.0343 - temporal_output_loss: 0.0038 - val_loss: 0.3299 - val_packet_output_loss: 0.0378 - val_protocol_output_loss: 0.2438 - val_temporal_output_loss: 0.0230
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0703 - packet_output_loss: 0.0321 - protocol_output_loss: 0.0337 - temporal_output_loss: 0.0045 - val_loss: 0.3245 - val_packet_output_loss: 0.0321 - val_protocol_output_loss: 0.2428 - val_temporal_output_loss: 0.0244
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training completed. Model and scalers saved.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import joblib

# Scikit-learn imports for classification and evaluation
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix, 
    classification_report,
    ConfusionMatrixDisplay
)

def extract_latent_representations(model_path, data_path, feature_groups):
    """
    Extract latent space representations from the trained autoencoder
    
    Parameters:
    - model_path: Path to the saved autoencoder model
    - data_path: Path to the input data CSV
    - feature_groups: Dictionary of feature groups
    
    Returns:
    - Latent space representations
    - Corresponding labels
    """
    # Load the model
    autoencoder = load_model(model_path, custom_objects={'MeanSquaredError': None})
    
    # Load scalers
    scaler_packet = joblib.load('packet_scaler.pkl')
    scaler_temporal = joblib.load('temporal_scaler.pkl')
    scaler_protocol = joblib.load('protocol_scaler.pkl')
    
    # Load data
    data = pd.read_csv(data_path)
    
    # Separate features
    X_packet = scaler_packet.transform(data[feature_groups['packet_features']])
    X_temporal = scaler_temporal.transform(data[feature_groups['temporal_features']])
    X_protocol = scaler_protocol.transform(data[feature_groups['protocol_features']])
    
    # Extract latent space representations
    encoder = Model(
        inputs=autoencoder.inputs, 
        outputs=autoencoder.get_layer('latent_space').output
    )
    latent_representations = encoder.predict([X_packet, X_temporal, X_protocol])
    
    # Extract labels (assuming the last column is the class label)
    y = data.iloc[:, -1]
    
    return latent_representations, y

def train_random_forest_on_latent_space(latent_reps, labels):
    """
    Train Random Forest Classifier on latent space representations
    
    Parameters:
    - latent_reps: Latent space representations
    - labels: Corresponding class labels
    
    Returns:
    - Trained Random Forest Classifier
    - Train and test sets
    """
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(
        latent_reps, labels, test_size=0.2, random_state=42
    )
    
    # Train Random Forest Classifier
    rf_classifier = RandomForestClassifier(
        n_estimators=100, 
        random_state=42, 
        n_jobs=-1
    )
    rf_classifier.fit(X_train, y_train)
    
    return rf_classifier, (X_train, X_test, y_train, y_test)

def evaluate_classification_performance(classifier, X_test, y_test):
    """
    Evaluate the performance of the Random Forest Classifier
    
    Parameters:
    - classifier: Trained Random Forest Classifier
    - X_test: Test features
    - y_test: Test labels
    
    Returns:
    - Dictionary of performance metrics
    """
    # Predict on test set
    y_pred = classifier.predict(X_test)
    
    # Calculate metrics
    metrics = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision (Weighted)': precision_score(y_test, y_pred, average='weighted'),
        'Recall (Weighted)': recall_score(y_test, y_pred, average='weighted'),
        'F1 Score (Weighted)': f1_score(y_test, y_pred, average='weighted')
    }
    
    # Print metrics
    print("\nClassification Performance Metrics:")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")
    
    # Print detailed classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot Confusion Matrix
    plt.figure(figsize=(10, 8))
    ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap='Blues', values_format='d')
    plt.title('Confusion Matrix for Latent Space Classification')
    plt.tight_layout()
    plt.show()
    plt.close()
    
    return metrics

def main():
    # Define feature groups (adjust according to your dataset)
    feature_groups = {
         'packet_features' : ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size'],

   
         'temporal_features' : ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur'],

         'protocol_features' : ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']
    }
    
    # Extract latent representations
    latent_representations, labels = extract_latent_representations(
        'multimodal_smoteenn_autoencoder.h5', 
        'balanced_smoteenn.csv',  # Your input dataset
        feature_groups
    )
    
    # Train Random Forest on latent space
    rf_classifier, (X_train, X_test, y_train, y_test) = train_random_forest_on_latent_space(
        latent_representations, labels
    )
    
    # Evaluate classification performance
    performance_metrics = evaluate_classification_performance(
        rf_classifier, X_test, y_test
    )
    
    # Optional: Feature importance in the latent space
    plt.figure(figsize=(10, 6))
    feature_importance = rf_classifier.feature_importances_
    plt.bar(range(len(feature_importance)), feature_importance)
    plt.title('Feature Importance in Latent Space')
    plt.xlabel('Latent Dimension')
    plt.ylabel('Importance')
    plt.tight_layout()
    plt.show()
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Performance Metrics:
# Accuracy: 0.9135
# Precision (Weighted): 0.9184
# Recall (Weighted): 0.9135
# F1 Score (Weighted): 0.9136
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.87      0.87      0.87        15
#            2       0.82      0.88      0.85        16
#            3       0.95      1.00      0.97        37
#            4       0.94      0.97      0.95        32
#            5       1.00      1.00      1.00        35
#            6       1.00      0.88      0.93        16
#            7       0.82      0.82      0.82        11
#            8       0.73      0.85      0.79        13
#            9       1.00      1.00      1.00        18
#           10       0.89      0.73      0.80        11
#           11       0.95      0.77      0.85        26
#           12       0.78      0.91      0.84        23
#           13       0.88      0.93      0.90        15
#           14       1.00      0.90      0.95        21
#
#     accuracy                           0.91       289
#    macro avg       0.90      0.89      0.89       289
# weighted avg       0.92      0.91      0.91       289

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import joblib

# Scikit-learn imports for classification and evaluation
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix, 
    classification_report,
    ConfusionMatrixDisplay
)

def extract_latent_representations(model_path, data_path, feature_groups):
    """
    Extract latent space representations from the trained autoencoder
    
    Parameters:
    - model_path: Path to the saved autoencoder model
    - data_path: Path to the input data CSV
    - feature_groups: Dictionary of feature groups
    
    Returns:
    - Latent space representations
    - Corresponding labels
    """
    # Load the model
    autoencoder = load_model(model_path, custom_objects={'MeanSquaredError': None})
    
    # Load scalers
    scaler_packet = joblib.load('packet_scaler.pkl')
    scaler_temporal = joblib.load('temporal_scaler.pkl')
    scaler_protocol = joblib.load('protocol_scaler.pkl')
    
    # Load data
    data = pd.read_csv(data_path)
    
    # Separate features
    X_packet = scaler_packet.transform(data[feature_groups['packet_features']])
    X_temporal = scaler_temporal.transform(data[feature_groups['temporal_features']])
    X_protocol = scaler_protocol.transform(data[feature_groups['protocol_features']])
    
    # Extract latent space representations
    encoder = Model(
        inputs=autoencoder.inputs, 
        outputs=autoencoder.get_layer('latent_space').output
    )
    latent_representations = encoder.predict([X_packet, X_temporal, X_protocol])
    
    # Extract labels (assuming the last column is the class label)
    y = data.iloc[:, -1]
    
    return latent_representations, y

def train_random_forest_on_latent_space(latent_reps, labels):
    """
    Train Random Forest Classifier on latent space representations
    
    Parameters:
    - latent_reps: Latent space representations
    - labels: Corresponding class labels
    
    Returns:
    - Trained Random Forest Classifier
    - Train and test sets
    """
    # Split the data
    X_train, y_train = (
        latent_reps, labels
    )
    
    # Train Random Forest Classifier
    rf_classifier = RandomForestClassifier(
        n_estimators=100, 
        random_state=42, 
        n_jobs=-1
    )
    rf_classifier.fit(X_train, y_train)
    
    return rf_classifier

def evaluate_classification_performance( classifier,X_test, y_test):
    """
    Evaluate the performance of the Random Forest Classifier
    
    Parameters:
    - classifier: Trained Random Forest Classifier
    - X_test: Test features
    - y_test: Test labels
    
    Returns:
    - Dictionary of performance metrics
    """
    # Predict on test set
    y_pred = classifier.predict(X_test)
    
    # Calculate metrics
    metrics = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision (Weighted)': precision_score(y_test, y_pred, average='weighted'),
        'Recall (Weighted)': recall_score(y_test, y_pred, average='weighted'),
        'F1 Score (Weighted)': f1_score(y_test, y_pred, average='weighted')
    }
    
    # Print metrics
    print("\nClassification Performance Metrics:")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")
    
    # Print detailed classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot Confusion Matrix
    plt.figure(figsize=(10, 8))
    ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap='Blues', values_format='d')
    plt.title('Confusion Matrix for Latent Space Classification')
    plt.tight_layout()
    plt.show()
    plt.close()
    
    return metrics

def main():
    # Define feature groups (adjust according to your dataset)
    feature_groups = {
         'packet_features' : ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size'],

   
         'temporal_features' : ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur'],

         'protocol_features' : ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']
    }
    
    # Extract latent representations
    latent_representations, labels = extract_latent_representations(
        'multimodal_smoteenn_autoencoder.h5', 
        'balanced_smoteenn.csv',  # Your input dataset
        feature_groups
    )

    latent_representations_test, labels_test = extract_latent_representations(
        'multimodal_smoteenn_autoencoder.h5', 
        'test_set.csv',  # Your input dataset
        feature_groups
    )
    
    # Train Random Forest on latent space
    classifier = train_random_forest_on_latent_space(
        latent_representations, labels
    )
    
    # Evaluate classification performance
    performance_metrics = evaluate_classification_performance(
       classifier, latent_representations_test, labels_test
    )
    
    # Optional: Feature importance in the latent space
    plt.figure(figsize=(10, 6))
    feature_importance = classifier.feature_importances_
    plt.bar(range(len(feature_importance)), feature_importance)
    plt.title('Feature Importance in Latent Space')
    plt.xlabel('Latent Dimension')
    plt.ylabel('Importance')
    plt.tight_layout()
    plt.show()
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Performance Metrics:
# Accuracy: 0.7667
# Precision (Weighted): 0.9267
# Recall (Weighted): 0.7667
# F1 Score (Weighted): 0.7949
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         4
#            4       0.40      1.00      0.57         2
#            5       1.00      1.00      1.00         2
#            6       1.00      0.83      0.91         6
#            7       1.00      0.33      0.50         3
#            8       0.00      0.00      0.00         0
#            9       1.00      1.00      1.00         1
#           10       1.00      0.50      0.67         2
#           11       0.00      0.00      0.00         0
#           12       0.50      1.00      0.67         2
#           13       1.00      0.50      0.67         2
#           14       1.00      0.60      0.75         5
#
#     accuracy                           0.77        30
#    macro avg       0.76      0.67      0.67        30
# weighted avg       0.93      0.77      0.79        30
