# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Processed.csv')

# Define feature groups
packet_features = ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size']

temporal_features = ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur']

protocol_features = ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']

# Separate features
X_packet = data[packet_features]
X_temporal = data[temporal_features]
X_protocol = data[protocol_features]

# Normalize features
scaler = MinMaxScaler()
X_packet = scaler.fit_transform(X_packet)
X_temporal = scaler.fit_transform(X_temporal)
X_protocol = scaler.fit_transform(X_protocol)

# Define input sizes
packet_input_size = len(packet_features)
temporal_input_size = len(temporal_features)
protocol_input_size = len(protocol_features)

# Define encoders for each modality
# Packet encoder
packet_input = Input(shape=(packet_input_size,), name="packet_input")
packet_encoded = Dense(64, activation='relu')(packet_input)
packet_encoded = Dense(32, activation='relu')(packet_encoded)

# Temporal encoder
temporal_input = Input(shape=(temporal_input_size,), name="temporal_input")
temporal_encoded = Dense(64, activation='relu')(temporal_input)
temporal_encoded = Dense(32, activation='relu')(temporal_encoded)

# Protocol encoder
protocol_input = Input(shape=(protocol_input_size,), name="protocol_input")
protocol_encoded = Dense(16, activation='relu')(protocol_input)
protocol_encoded = Dense(8, activation='relu')(protocol_encoded)

# Combine the encoded representations
combined = Concatenate()([packet_encoded, temporal_encoded, protocol_encoded])

# Shared latent space
latent = Dense(32, activation='relu', name="latent_space")(combined)

# Decoders for each modality
# Packet decoder
packet_decoded = Dense(32, activation='relu')(latent)
packet_decoded = Dense(64, activation='relu')(packet_decoded)
packet_decoded = Dense(packet_input_size, activation='sigmoid', name="packet_output")(packet_decoded)

# Temporal decoder
temporal_decoded = Dense(32, activation='relu')(latent)
temporal_decoded = Dense(64, activation='relu')(temporal_decoded)
temporal_decoded = Dense(temporal_input_size, activation='sigmoid', name="temporal_output")(temporal_decoded)

# Protocol decoder
protocol_decoded = Dense(8, activation='relu')(latent)
protocol_decoded = Dense(16, activation='relu')(protocol_decoded)
protocol_decoded = Dense(protocol_input_size, activation='sigmoid', name="protocol_output")(protocol_decoded)

# Build the autoencoder model
autoencoder = Model(inputs=[packet_input, temporal_input, protocol_input], 
                    outputs=[packet_decoded, temporal_decoded, protocol_decoded])

# Compile the model
autoencoder.compile(optimizer='adam', 
                    loss={'packet_output': 'mse', 
                          'temporal_output': 'mse', 
                          'protocol_output': 'mse'})

# Print the model summary
autoencoder.summary()

# Train the autoencoder
history = autoencoder.fit([X_packet, X_temporal, X_protocol], 
                          [X_packet, X_temporal, X_protocol], 
                          epochs=50, 
                          batch_size=32, 
                          validation_split=0.2)

# Save the trained model
autoencoder.save("multimodal_autoencoder.h5")

# Extract the latent space representations
encoder = Model(inputs=[packet_input, temporal_input, protocol_input], outputs=latent)
latent_representations = encoder.predict([X_packet, X_temporal, X_protocol])

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ packet_input (InputLayer)     │ (None, 12)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ temporal_input (InputLayer)   │ (None, 10)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ protocol_input (InputLayer)   │ (None, 5)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 64)                │             832 │ packet_input[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_14 (Dense)              │ (None, 64)                │             704 │ temporal_input[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_16 (Dense)              │ (None, 16)                │              96 │ protocol_input[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 32)                │           2,080 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_15 (Dense)              │ (None, 32)                │           2,080 │ dense_14[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_17 (Dense)              │ (None, 8)                 │             136 │ dense_16[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 72)                │               0 │ dense_13[0][0],            │
# │                               │                           │                 │ dense_15[0][0],            │
# │                               │                           │                 │ dense_17[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ latent_space (Dense)          │ (None, 32)                │           2,336 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_18 (Dense)              │ (None, 32)                │           1,056 │ latent_space[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_20 (Dense)              │ (None, 32)                │           1,056 │ latent_space[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_22 (Dense)              │ (None, 8)                 │             264 │ latent_space[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_19 (Dense)              │ (None, 64)                │           2,112 │ dense_18[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_21 (Dense)              │ (None, 64)                │           2,112 │ dense_20[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_23 (Dense)              │ (None, 16)                │             144 │ dense_22[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ packet_output (Dense)         │ (None, 12)                │             780 │ dense_19[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ temporal_output (Dense)       │ (None, 10)                │             650 │ dense_21[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ protocol_output (Dense)       │ (None, 5)                 │              85 │ dense_23[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 16,523 (64.54 KB)
#  Trainable params: 16,523 (64.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 3.7531 - packet_output_loss: 1.3885 - protocol_output_loss: 1.1930 - temporal_output_loss: 1.1727 - val_loss: 2.9691 - val_packet_output_loss: 0.8227 - val_protocol_output_loss: 1.0153 - val_temporal_output_loss: 1.0910
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9297 - packet_output_loss: 1.0147 - protocol_output_loss: 1.0746 - temporal_output_loss: 0.8400 - val_loss: 2.3392 - val_packet_output_loss: 0.6406 - val_protocol_output_loss: 0.9182 - val_temporal_output_loss: 0.7636
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8214 - packet_output_loss: 1.0546 - protocol_output_loss: 0.9772 - temporal_output_loss: 0.7889 - val_loss: 2.1888 - val_packet_output_loss: 0.5558 - val_protocol_output_loss: 0.8947 - val_temporal_output_loss: 0.7242
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3290 - packet_output_loss: 0.7353 - protocol_output_loss: 0.9602 - temporal_output_loss: 0.6346 - val_loss: 2.1062 - val_packet_output_loss: 0.4929 - val_protocol_output_loss: 0.8777 - val_temporal_output_loss: 0.7174
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7407 - packet_output_loss: 1.0691 - protocol_output_loss: 0.8910 - temporal_output_loss: 0.7798 - val_loss: 1.9897 - val_packet_output_loss: 0.4136 - val_protocol_output_loss: 0.8486 - val_temporal_output_loss: 0.7039
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0379 - packet_output_loss: 0.5688 - protocol_output_loss: 0.8510 - temporal_output_loss: 0.6188 - val_loss: 1.9456 - val_packet_output_loss: 0.3795 - val_protocol_output_loss: 0.8395 - val_temporal_output_loss: 0.7018
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1021 - packet_output_loss: 0.6499 - protocol_output_loss: 0.7923 - temporal_output_loss: 0.6592 - val_loss: 1.9288 - val_packet_output_loss: 0.3729 - val_protocol_output_loss: 0.8309 - val_temporal_output_loss: 0.6992
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3779 - packet_output_loss: 0.9767 - protocol_output_loss: 0.8182 - temporal_output_loss: 0.5846 - val_loss: 1.9129 - val_packet_output_loss: 0.3697 - val_protocol_output_loss: 0.8186 - val_temporal_output_loss: 0.6971
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4720 - packet_output_loss: 0.6933 - protocol_output_loss: 0.7958 - temporal_output_loss: 0.9820 - val_loss: 1.9003 - val_packet_output_loss: 0.3668 - val_protocol_output_loss: 0.8088 - val_temporal_output_loss: 0.6970
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0587 - packet_output_loss: 0.7635 - protocol_output_loss: 0.7901 - temporal_output_loss: 0.5046 - val_loss: 1.9056 - val_packet_output_loss: 0.3682 - val_protocol_output_loss: 0.8101 - val_temporal_output_loss: 0.6962
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1055 - packet_output_loss: 0.6866 - protocol_output_loss: 0.7473 - temporal_output_loss: 0.6719 - val_loss: 1.8919 - val_packet_output_loss: 0.3664 - val_protocol_output_loss: 0.7969 - val_temporal_output_loss: 0.6958
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1352 - packet_output_loss: 0.8195 - protocol_output_loss: 0.7086 - temporal_output_loss: 0.6070 - val_loss: 1.8595 - val_packet_output_loss: 0.3656 - val_protocol_output_loss: 0.7651 - val_temporal_output_loss: 0.6950
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1763 - packet_output_loss: 0.7969 - protocol_output_loss: 0.7223 - temporal_output_loss: 0.6567 - val_loss: 1.8403 - val_packet_output_loss: 0.3654 - val_protocol_output_loss: 0.7442 - val_temporal_output_loss: 0.6942
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5442 - packet_output_loss: 1.1642 - protocol_output_loss: 0.7360 - temporal_output_loss: 0.6462 - val_loss: 1.8100 - val_packet_output_loss: 0.3667 - val_protocol_output_loss: 0.7100 - val_temporal_output_loss: 0.6936
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0144 - packet_output_loss: 0.6447 - protocol_output_loss: 0.7012 - temporal_output_loss: 0.6685 - val_loss: 1.7164 - val_packet_output_loss: 0.3664 - val_protocol_output_loss: 0.6130 - val_temporal_output_loss: 0.6933
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8657 - packet_output_loss: 0.5831 - protocol_output_loss: 0.6601 - temporal_output_loss: 0.6218 - val_loss: 1.7011 - val_packet_output_loss: 0.3637 - val_protocol_output_loss: 0.5989 - val_temporal_output_loss: 0.6934
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9629 - packet_output_loss: 0.6858 - protocol_output_loss: 0.6733 - temporal_output_loss: 0.6059 - val_loss: 1.6927 - val_packet_output_loss: 0.3618 - val_protocol_output_loss: 0.5926 - val_temporal_output_loss: 0.6926
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4126 - packet_output_loss: 1.0931 - protocol_output_loss: 0.6677 - temporal_output_loss: 0.6513 - val_loss: 1.6881 - val_packet_output_loss: 0.3608 - val_protocol_output_loss: 0.5880 - val_temporal_output_loss: 0.6923
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2583 - packet_output_loss: 1.0224 - protocol_output_loss: 0.6813 - temporal_output_loss: 0.5544 - val_loss: 1.6861 - val_packet_output_loss: 0.3602 - val_protocol_output_loss: 0.5865 - val_temporal_output_loss: 0.6923
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2564 - packet_output_loss: 0.7567 - protocol_output_loss: 0.6663 - temporal_output_loss: 0.8323 - val_loss: 1.6837 - val_packet_output_loss: 0.3588 - val_protocol_output_loss: 0.5854 - val_temporal_output_loss: 0.6922
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3608 - packet_output_loss: 0.8367 - protocol_output_loss: 0.6893 - temporal_output_loss: 0.8340 - val_loss: 1.6846 - val_packet_output_loss: 0.3580 - val_protocol_output_loss: 0.5868 - val_temporal_output_loss: 0.6919
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9763 - packet_output_loss: 0.5225 - protocol_output_loss: 0.6466 - temporal_output_loss: 0.8067 - val_loss: 1.6818 - val_packet_output_loss: 0.3576 - val_protocol_output_loss: 0.5846 - val_temporal_output_loss: 0.6921
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8659 - packet_output_loss: 0.5538 - protocol_output_loss: 0.6590 - temporal_output_loss: 0.6522 - val_loss: 1.6813 - val_packet_output_loss: 0.3587 - val_protocol_output_loss: 0.5835 - val_temporal_output_loss: 0.6914
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1831 - packet_output_loss: 0.7577 - protocol_output_loss: 0.6459 - temporal_output_loss: 0.7787 - val_loss: 1.6108 - val_packet_output_loss: 0.3582 - val_protocol_output_loss: 0.5157 - val_temporal_output_loss: 0.6918
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0395 - packet_output_loss: 0.6919 - protocol_output_loss: 0.6595 - temporal_output_loss: 0.6871 - val_loss: 1.5791 - val_packet_output_loss: 0.3591 - val_protocol_output_loss: 0.4734 - val_temporal_output_loss: 0.6917
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0651 - packet_output_loss: 0.5454 - protocol_output_loss: 0.6583 - temporal_output_loss: 0.8605 - val_loss: 1.5738 - val_packet_output_loss: 0.3577 - val_protocol_output_loss: 0.4700 - val_temporal_output_loss: 0.6914
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5218 - packet_output_loss: 0.8706 - protocol_output_loss: 0.6357 - temporal_output_loss: 1.0149 - val_loss: 1.5772 - val_packet_output_loss: 0.3586 - val_protocol_output_loss: 0.4717 - val_temporal_output_loss: 0.6916
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2422 - packet_output_loss: 0.8527 - protocol_output_loss: 0.6713 - temporal_output_loss: 0.7188 - val_loss: 1.5739 - val_packet_output_loss: 0.3580 - val_protocol_output_loss: 0.4693 - val_temporal_output_loss: 0.6912
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7393 - packet_output_loss: 0.5517 - protocol_output_loss: 0.6408 - temporal_output_loss: 0.5450 - val_loss: 1.5718 - val_packet_output_loss: 0.3576 - val_protocol_output_loss: 0.4682 - val_temporal_output_loss: 0.6912
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0937 - packet_output_loss: 0.5878 - protocol_output_loss: 0.6527 - temporal_output_loss: 0.8526 - val_loss: 1.5715 - val_packet_output_loss: 0.3574 - val_protocol_output_loss: 0.4677 - val_temporal_output_loss: 0.6913
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9326 - packet_output_loss: 0.7688 - protocol_output_loss: 0.6412 - temporal_output_loss: 0.5213 - val_loss: 1.5688 - val_packet_output_loss: 0.3566 - val_protocol_output_loss: 0.4663 - val_temporal_output_loss: 0.6910
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8994 - packet_output_loss: 0.6477 - protocol_output_loss: 0.6592 - temporal_output_loss: 0.5929 - val_loss: 1.5702 - val_packet_output_loss: 0.3574 - val_protocol_output_loss: 0.4664 - val_temporal_output_loss: 0.6911
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0978 - packet_output_loss: 0.7694 - protocol_output_loss: 0.6410 - temporal_output_loss: 0.6875 - val_loss: 1.5681 - val_packet_output_loss: 0.3573 - val_protocol_output_loss: 0.4642 - val_temporal_output_loss: 0.6910
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9876 - packet_output_loss: 0.6996 - protocol_output_loss: 0.5958 - temporal_output_loss: 0.6915 - val_loss: 1.5687 - val_packet_output_loss: 0.3570 - val_protocol_output_loss: 0.4655 - val_temporal_output_loss: 0.6913
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9127 - packet_output_loss: 0.7432 - protocol_output_loss: 0.6489 - temporal_output_loss: 0.5201 - val_loss: 1.5692 - val_packet_output_loss: 0.3566 - val_protocol_output_loss: 0.4663 - val_temporal_output_loss: 0.6912
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0151 - packet_output_loss: 0.8051 - protocol_output_loss: 0.6356 - temporal_output_loss: 0.5740 - val_loss: 1.5667 - val_packet_output_loss: 0.3566 - val_protocol_output_loss: 0.4639 - val_temporal_output_loss: 0.6910
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0198 - packet_output_loss: 0.6934 - protocol_output_loss: 0.6384 - temporal_output_loss: 0.6873 - val_loss: 1.5691 - val_packet_output_loss: 0.3570 - val_protocol_output_loss: 0.4660 - val_temporal_output_loss: 0.6910
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4329 - packet_output_loss: 1.1803 - protocol_output_loss: 0.6307 - temporal_output_loss: 0.6223 - val_loss: 1.5682 - val_packet_output_loss: 0.3567 - val_protocol_output_loss: 0.4654 - val_temporal_output_loss: 0.6910
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8089 - packet_output_loss: 0.5553 - protocol_output_loss: 0.6533 - temporal_output_loss: 0.5986 - val_loss: 1.5673 - val_packet_output_loss: 0.3569 - val_protocol_output_loss: 0.4644 - val_temporal_output_loss: 0.6909
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8492 - packet_output_loss: 0.7162 - protocol_output_loss: 0.6439 - temporal_output_loss: 0.4886 - val_loss: 1.5671 - val_packet_output_loss: 0.3570 - val_protocol_output_loss: 0.4642 - val_temporal_output_loss: 0.6907
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9774 - packet_output_loss: 0.6132 - protocol_output_loss: 0.6539 - temporal_output_loss: 0.7094 - val_loss: 1.5670 - val_packet_output_loss: 0.3575 - val_protocol_output_loss: 0.4633 - val_temporal_output_loss: 0.6911
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7671 - packet_output_loss: 0.6990 - protocol_output_loss: 0.6244 - temporal_output_loss: 0.4428 - val_loss: 1.5687 - val_packet_output_loss: 0.3566 - val_protocol_output_loss: 0.4663 - val_temporal_output_loss: 0.6908
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9982 - packet_output_loss: 0.5936 - protocol_output_loss: 0.6639 - temporal_output_loss: 0.7403 - val_loss: 1.5656 - val_packet_output_loss: 0.3567 - val_protocol_output_loss: 0.4628 - val_temporal_output_loss: 0.6910
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9377 - packet_output_loss: 0.5406 - protocol_output_loss: 0.6644 - temporal_output_loss: 0.7318 - val_loss: 1.5648 - val_packet_output_loss: 0.3565 - val_protocol_output_loss: 0.4625 - val_temporal_output_loss: 0.6907
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0122 - packet_output_loss: 0.6544 - protocol_output_loss: 0.6540 - temporal_output_loss: 0.7058 - val_loss: 1.5660 - val_packet_output_loss: 0.3562 - val_protocol_output_loss: 0.4642 - val_temporal_output_loss: 0.6906
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4357 - packet_output_loss: 0.9174 - protocol_output_loss: 0.6315 - temporal_output_loss: 0.8877 - val_loss: 1.5648 - val_packet_output_loss: 0.3567 - val_protocol_output_loss: 0.4629 - val_temporal_output_loss: 0.6903
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1555 - packet_output_loss: 0.5971 - protocol_output_loss: 0.6592 - temporal_output_loss: 0.8986 - val_loss: 1.5668 - val_packet_output_loss: 0.3566 - val_protocol_output_loss: 0.4647 - val_temporal_output_loss: 0.6904
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8554 - packet_output_loss: 0.6173 - protocol_output_loss: 0.6581 - temporal_output_loss: 0.5796 - val_loss: 1.5677 - val_packet_output_loss: 0.3579 - val_protocol_output_loss: 0.4643 - val_temporal_output_loss: 0.6905
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0808 - packet_output_loss: 0.7725 - protocol_output_loss: 0.6480 - temporal_output_loss: 0.6597 - val_loss: 1.5631 - val_packet_output_loss: 0.3563 - val_protocol_output_loss: 0.4612 - val_temporal_output_loss: 0.6904
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9768 - packet_output_loss: 0.7388 - protocol_output_loss: 0.6521 - temporal_output_loss: 0.5877 - val_loss: 1.5668 - val_packet_output_loss: 0.3570 - val_protocol_output_loss: 0.4626 - val_temporal_output_loss: 0.6919
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.losses import MeanSquaredError

# Instantiate the Mean Squared Error loss
mse = MeanSquaredError()
from tensorflow.keras.metrics import MeanSquaredError
import matplotlib.pyplot as plt

def create_multimodal_autoencoder(packet_input_size, temporal_input_size, protocol_input_size):
    # Define input layers for each modality
    packet_input = Input(shape=(packet_input_size,), name="packet_input")
    temporal_input = Input(shape=(temporal_input_size,), name="temporal_input")
    protocol_input = Input(shape=(protocol_input_size,), name="protocol_input")

    # Packet encoder
    packet_encoded = Dense(64, activation='relu')(packet_input)
    packet_encoded = Dense(32, activation='relu')(packet_encoded)

    # Temporal encoder
    temporal_encoded = Dense(64, activation='relu')(temporal_input)
    temporal_encoded = Dense(32, activation='relu')(temporal_encoded)

    # Protocol encoder
    protocol_encoded = Dense(16, activation='relu')(protocol_input)
    protocol_encoded = Dense(8, activation='relu')(protocol_encoded)

    # Combine the encoded representations
    combined = Concatenate()([packet_encoded, temporal_encoded, protocol_encoded])

    # Shared latent space
    latent = Dense(32, activation='relu', name="latent_space")(combined)

    # Decoders for each modality
    # Packet decoder
    packet_decoded = Dense(32, activation='relu')(latent)
    packet_decoded = Dense(64, activation='relu')(packet_decoded)
    packet_decoded = Dense(packet_input_size, activation='linear', name="packet_output")(packet_decoded)

    # Temporal decoder
    temporal_decoded = Dense(32, activation='relu')(latent)
    temporal_decoded = Dense(64, activation='relu')(temporal_decoded)
    temporal_decoded = Dense(temporal_input_size, activation='linear', name="temporal_output")(temporal_decoded)

    # Protocol decoder
    protocol_decoded = Dense(8, activation='relu')(latent)
    protocol_decoded = Dense(16, activation='relu')(protocol_decoded)
    protocol_decoded = Dense(protocol_input_size, activation='linear', name="protocol_output")(protocol_decoded)

    # Build the autoencoder model
    autoencoder = Model(
        inputs=[packet_input, temporal_input, protocol_input], 
        outputs=[packet_decoded, temporal_decoded, protocol_decoded]
    )

    # Compile the model
    autoencoder.compile(
        optimizer='adam', 
        loss={
            'packet_output': 'mean_squared_error', 
            'temporal_output': 'mean_squared_error', 
            'protocol_output': 'mean_squared_error'
        }
    )

    return autoencoder

def train_multimodal_autoencoder(data_path):
    # Load the dataset
    data = pd.read_csv(data_path)

    # Define feature groups
    packet_features = ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size']

   
    temporal_features = ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur']

    protocol_features = ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']

    # Separate features
    X_packet = data[packet_features]
    X_temporal = data[temporal_features]
    X_protocol = data[protocol_features]

    # Normalize features
    scaler_packet = StandardScaler()
    scaler_temporal = StandardScaler()
    scaler_protocol = StandardScaler()

    X_packet_scaled = scaler_packet.fit_transform(X_packet)
    X_temporal_scaled = scaler_temporal.fit_transform(X_temporal)
    X_protocol_scaled = scaler_protocol.fit_transform(X_protocol)

    # Create and train the autoencoder
    autoencoder = create_multimodal_autoencoder(
        len(packet_features), 
        len(temporal_features), 
        len(protocol_features)
    )

    # Train the autoencoder
    history = autoencoder.fit(
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        epochs=50, 
        batch_size=32, 
        validation_split=0.2,
        verbose=1
    )

    # Save the model and scalers
    autoencoder.save("multimodal_network_autoencoder.h5", save_format='h5')
    import joblib
    joblib.dump(scaler_packet, 'packet_scaler.pkl')
    joblib.dump(scaler_temporal, 'temporal_scaler.pkl')
    joblib.dump(scaler_protocol, 'protocol_scaler.pkl')

    # Plot the training and validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Multimodal Autoencoder Training and Validation Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()
    plt.close()

    print("Model training completed. Model and scalers saved.")

# Example usage
if __name__ == "__main__":
    train_multimodal_autoencoder('Processed.csv')
# Out:
# Epoch 1/50
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 2.8864 - packet_output_loss: 0.8923 - protocol_output_loss: 1.0132 - temporal_output_loss: 0.9793 - val_loss: 2.2173 - val_packet_output_loss: 0.5755 - val_protocol_output_loss: 0.8253 - val_temporal_output_loss: 0.7900
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2332 - packet_output_loss: 0.8384 - protocol_output_loss: 0.8615 - temporal_output_loss: 0.5324 - val_loss: 1.3843 - val_packet_output_loss: 0.2632 - val_protocol_output_loss: 0.7594 - val_temporal_output_loss: 0.3594
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2877 - packet_output_loss: 0.3191 - protocol_output_loss: 0.6559 - temporal_output_loss: 0.3220 - val_loss: 0.9613 - val_packet_output_loss: 0.1546 - val_protocol_output_loss: 0.6350 - val_temporal_output_loss: 0.1830
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9585 - packet_output_loss: 0.3293 - protocol_output_loss: 0.4828 - temporal_output_loss: 0.1462 - val_loss: 0.8312 - val_packet_output_loss: 0.1374 - val_protocol_output_loss: 0.5712 - val_temporal_output_loss: 0.1394
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7934 - packet_output_loss: 0.3420 - protocol_output_loss: 0.3570 - temporal_output_loss: 0.0946 - val_loss: 0.7282 - val_packet_output_loss: 0.1136 - val_protocol_output_loss: 0.5189 - val_temporal_output_loss: 0.1164
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5529 - packet_output_loss: 0.1461 - protocol_output_loss: 0.2809 - temporal_output_loss: 0.1259 - val_loss: 0.6660 - val_packet_output_loss: 0.0961 - val_protocol_output_loss: 0.4980 - val_temporal_output_loss: 0.0933
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4455 - packet_output_loss: 0.1218 - protocol_output_loss: 0.2510 - temporal_output_loss: 0.0726 - val_loss: 0.6055 - val_packet_output_loss: 0.0863 - val_protocol_output_loss: 0.4456 - val_temporal_output_loss: 0.0908
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3887 - packet_output_loss: 0.0909 - protocol_output_loss: 0.2283 - temporal_output_loss: 0.0694 - val_loss: 0.5635 - val_packet_output_loss: 0.0850 - val_protocol_output_loss: 0.4152 - val_temporal_output_loss: 0.0784
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3204 - packet_output_loss: 0.0700 - protocol_output_loss: 0.1856 - temporal_output_loss: 0.0647 - val_loss: 0.5084 - val_packet_output_loss: 0.0700 - val_protocol_output_loss: 0.3759 - val_temporal_output_loss: 0.0770
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2939 - packet_output_loss: 0.0704 - protocol_output_loss: 0.1633 - temporal_output_loss: 0.0602 - val_loss: 0.4326 - val_packet_output_loss: 0.0666 - val_protocol_output_loss: 0.3236 - val_temporal_output_loss: 0.0529
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2618 - packet_output_loss: 0.0592 - protocol_output_loss: 0.1595 - temporal_output_loss: 0.0430 - val_loss: 0.3957 - val_packet_output_loss: 0.0576 - val_protocol_output_loss: 0.3019 - val_temporal_output_loss: 0.0472
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2188 - packet_output_loss: 0.0488 - protocol_output_loss: 0.1254 - temporal_output_loss: 0.0444 - val_loss: 0.3446 - val_packet_output_loss: 0.0577 - val_protocol_output_loss: 0.2551 - val_temporal_output_loss: 0.0425
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1830 - packet_output_loss: 0.0412 - protocol_output_loss: 0.1065 - temporal_output_loss: 0.0353 - val_loss: 0.3008 - val_packet_output_loss: 0.0527 - val_protocol_output_loss: 0.2125 - val_temporal_output_loss: 0.0432
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1587 - packet_output_loss: 0.0396 - protocol_output_loss: 0.0866 - temporal_output_loss: 0.0324 - val_loss: 0.2662 - val_packet_output_loss: 0.0495 - val_protocol_output_loss: 0.1839 - val_temporal_output_loss: 0.0371
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1490 - packet_output_loss: 0.0375 - protocol_output_loss: 0.0774 - temporal_output_loss: 0.0341 - val_loss: 0.2350 - val_packet_output_loss: 0.0493 - val_protocol_output_loss: 0.1561 - val_temporal_output_loss: 0.0350
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1332 - packet_output_loss: 0.0383 - protocol_output_loss: 0.0623 - temporal_output_loss: 0.0325 - val_loss: 0.2152 - val_packet_output_loss: 0.0422 - val_protocol_output_loss: 0.1354 - val_temporal_output_loss: 0.0422
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1165 - packet_output_loss: 0.0338 - protocol_output_loss: 0.0513 - temporal_output_loss: 0.0314 - val_loss: 0.1852 - val_packet_output_loss: 0.0398 - val_protocol_output_loss: 0.1196 - val_temporal_output_loss: 0.0314
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1048 - packet_output_loss: 0.0260 - protocol_output_loss: 0.0523 - temporal_output_loss: 0.0265 - val_loss: 0.1868 - val_packet_output_loss: 0.0370 - val_protocol_output_loss: 0.1136 - val_temporal_output_loss: 0.0402
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1010 - packet_output_loss: 0.0263 - protocol_output_loss: 0.0470 - temporal_output_loss: 0.0276 - val_loss: 0.1770 - val_packet_output_loss: 0.0395 - val_protocol_output_loss: 0.1006 - val_temporal_output_loss: 0.0409
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1027 - packet_output_loss: 0.0285 - protocol_output_loss: 0.0453 - temporal_output_loss: 0.0289 - val_loss: 0.1481 - val_packet_output_loss: 0.0331 - val_protocol_output_loss: 0.0917 - val_temporal_output_loss: 0.0274
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0864 - packet_output_loss: 0.0253 - protocol_output_loss: 0.0384 - temporal_output_loss: 0.0227 - val_loss: 0.1420 - val_packet_output_loss: 0.0317 - val_protocol_output_loss: 0.0877 - val_temporal_output_loss: 0.0267
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0732 - packet_output_loss: 0.0209 - protocol_output_loss: 0.0349 - temporal_output_loss: 0.0173 - val_loss: 0.1371 - val_packet_output_loss: 0.0298 - val_protocol_output_loss: 0.0835 - val_temporal_output_loss: 0.0274
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0752 - packet_output_loss: 0.0210 - protocol_output_loss: 0.0327 - temporal_output_loss: 0.0216 - val_loss: 0.1237 - val_packet_output_loss: 0.0280 - val_protocol_output_loss: 0.0755 - val_temporal_output_loss: 0.0241
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0769 - packet_output_loss: 0.0217 - protocol_output_loss: 0.0374 - temporal_output_loss: 0.0178 - val_loss: 0.1167 - val_packet_output_loss: 0.0264 - val_protocol_output_loss: 0.0698 - val_temporal_output_loss: 0.0230
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0720 - packet_output_loss: 0.0201 - protocol_output_loss: 0.0352 - temporal_output_loss: 0.0166 - val_loss: 0.1137 - val_packet_output_loss: 0.0280 - val_protocol_output_loss: 0.0648 - val_temporal_output_loss: 0.0239
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0665 - packet_output_loss: 0.0213 - protocol_output_loss: 0.0278 - temporal_output_loss: 0.0175 - val_loss: 0.1078 - val_packet_output_loss: 0.0291 - val_protocol_output_loss: 0.0568 - val_temporal_output_loss: 0.0245
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0623 - packet_output_loss: 0.0176 - protocol_output_loss: 0.0271 - temporal_output_loss: 0.0176 - val_loss: 0.1056 - val_packet_output_loss: 0.0262 - val_protocol_output_loss: 0.0595 - val_temporal_output_loss: 0.0231
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0630 - packet_output_loss: 0.0188 - protocol_output_loss: 0.0275 - temporal_output_loss: 0.0166 - val_loss: 0.1003 - val_packet_output_loss: 0.0248 - val_protocol_output_loss: 0.0563 - val_temporal_output_loss: 0.0220
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0668 - packet_output_loss: 0.0208 - protocol_output_loss: 0.0305 - temporal_output_loss: 0.0156 - val_loss: 0.0960 - val_packet_output_loss: 0.0254 - val_protocol_output_loss: 0.0490 - val_temporal_output_loss: 0.0238
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0922 - packet_output_loss: 0.0220 - protocol_output_loss: 0.0286 - temporal_output_loss: 0.0415 - val_loss: 0.1069 - val_packet_output_loss: 0.0249 - val_protocol_output_loss: 0.0485 - val_temporal_output_loss: 0.0345
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0752 - packet_output_loss: 0.0196 - protocol_output_loss: 0.0216 - temporal_output_loss: 0.0339 - val_loss: 0.0921 - val_packet_output_loss: 0.0227 - val_protocol_output_loss: 0.0474 - val_temporal_output_loss: 0.0241
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0517 - packet_output_loss: 0.0179 - protocol_output_loss: 0.0207 - temporal_output_loss: 0.0131 - val_loss: 0.0927 - val_packet_output_loss: 0.0223 - val_protocol_output_loss: 0.0498 - val_temporal_output_loss: 0.0231
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0470 - packet_output_loss: 0.0148 - protocol_output_loss: 0.0198 - temporal_output_loss: 0.0123 - val_loss: 0.0856 - val_packet_output_loss: 0.0229 - val_protocol_output_loss: 0.0425 - val_temporal_output_loss: 0.0220
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0537 - packet_output_loss: 0.0151 - protocol_output_loss: 0.0223 - temporal_output_loss: 0.0163 - val_loss: 0.0886 - val_packet_output_loss: 0.0222 - val_protocol_output_loss: 0.0463 - val_temporal_output_loss: 0.0220
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0529 - packet_output_loss: 0.0182 - protocol_output_loss: 0.0220 - temporal_output_loss: 0.0127 - val_loss: 0.0869 - val_packet_output_loss: 0.0220 - val_protocol_output_loss: 0.0441 - val_temporal_output_loss: 0.0230
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0718 - packet_output_loss: 0.0260 - protocol_output_loss: 0.0272 - temporal_output_loss: 0.0186 - val_loss: 0.0863 - val_packet_output_loss: 0.0217 - val_protocol_output_loss: 0.0458 - val_temporal_output_loss: 0.0209
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0622 - packet_output_loss: 0.0197 - protocol_output_loss: 0.0205 - temporal_output_loss: 0.0220 - val_loss: 0.0783 - val_packet_output_loss: 0.0201 - val_protocol_output_loss: 0.0397 - val_temporal_output_loss: 0.0197
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0512 - packet_output_loss: 0.0162 - protocol_output_loss: 0.0204 - temporal_output_loss: 0.0146 - val_loss: 0.0780 - val_packet_output_loss: 0.0201 - val_protocol_output_loss: 0.0392 - val_temporal_output_loss: 0.0197
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0539 - packet_output_loss: 0.0235 - protocol_output_loss: 0.0177 - temporal_output_loss: 0.0127 - val_loss: 0.0749 - val_packet_output_loss: 0.0199 - val_protocol_output_loss: 0.0387 - val_temporal_output_loss: 0.0180
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0467 - packet_output_loss: 0.0149 - protocol_output_loss: 0.0181 - temporal_output_loss: 0.0138 - val_loss: 0.0775 - val_packet_output_loss: 0.0185 - val_protocol_output_loss: 0.0423 - val_temporal_output_loss: 0.0182
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0445 - packet_output_loss: 0.0136 - protocol_output_loss: 0.0188 - temporal_output_loss: 0.0121 - val_loss: 0.0735 - val_packet_output_loss: 0.0165 - val_protocol_output_loss: 0.0403 - val_temporal_output_loss: 0.0178
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0400 - packet_output_loss: 0.0131 - protocol_output_loss: 0.0170 - temporal_output_loss: 0.0099 - val_loss: 0.0762 - val_packet_output_loss: 0.0214 - val_protocol_output_loss: 0.0381 - val_temporal_output_loss: 0.0180
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0398 - packet_output_loss: 0.0136 - protocol_output_loss: 0.0166 - temporal_output_loss: 0.0095 - val_loss: 0.0737 - val_packet_output_loss: 0.0169 - val_protocol_output_loss: 0.0386 - val_temporal_output_loss: 0.0193
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0409 - packet_output_loss: 0.0124 - protocol_output_loss: 0.0186 - temporal_output_loss: 0.0099 - val_loss: 0.0700 - val_packet_output_loss: 0.0174 - val_protocol_output_loss: 0.0370 - val_temporal_output_loss: 0.0169
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0403 - packet_output_loss: 0.0129 - protocol_output_loss: 0.0178 - temporal_output_loss: 0.0096 - val_loss: 0.0731 - val_packet_output_loss: 0.0163 - val_protocol_output_loss: 0.0393 - val_temporal_output_loss: 0.0182
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0393 - packet_output_loss: 0.0124 - protocol_output_loss: 0.0169 - temporal_output_loss: 0.0100 - val_loss: 0.0710 - val_packet_output_loss: 0.0178 - val_protocol_output_loss: 0.0376 - val_temporal_output_loss: 0.0170
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0404 - packet_output_loss: 0.0119 - protocol_output_loss: 0.0191 - temporal_output_loss: 0.0095 - val_loss: 0.0716 - val_packet_output_loss: 0.0200 - val_protocol_output_loss: 0.0349 - val_temporal_output_loss: 0.0175
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0459 - packet_output_loss: 0.0162 - protocol_output_loss: 0.0151 - temporal_output_loss: 0.0146 - val_loss: 0.0678 - val_packet_output_loss: 0.0183 - val_protocol_output_loss: 0.0339 - val_temporal_output_loss: 0.0161
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0402 - packet_output_loss: 0.0129 - protocol_output_loss: 0.0162 - temporal_output_loss: 0.0112 - val_loss: 0.0690 - val_packet_output_loss: 0.0200 - val_protocol_output_loss: 0.0317 - val_temporal_output_loss: 0.0172
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0363 - packet_output_loss: 0.0126 - protocol_output_loss: 0.0150 - temporal_output_loss: 0.0088 - val_loss: 0.0698 - val_packet_output_loss: 0.0174 - val_protocol_output_loss: 0.0353 - val_temporal_output_loss: 0.0178
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training completed. Model and scalers saved.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
import joblib
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Model

def test_multimodal_autoencoder(test_data_path):
    # Load the trained model and scalers
    try:
        # Explicitly specify the custom_objects if needed
        autoencoder = load_model('multimodal_network_autoencoder.h5', 
                                 custom_objects={'MeanSquaredError': MeanSquaredError})
        
        scaler_packet = joblib.load('packet_scaler.pkl')
        scaler_temporal = joblib.load('temporal_scaler.pkl')
        scaler_protocol = joblib.load('protocol_scaler.pkl')
    except Exception as e:
        print(f"Error loading model or scalers: {e}")
        return

    # Load test data
    test_data = pd.read_csv(test_data_path)

    # Define feature groups
    packet_features = ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size']

   
    temporal_features = ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur']

    protocol_features = ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']
    # Separate and scale test features
    X_packet_test = scaler_packet.transform(test_data[packet_features])
    X_temporal_test = scaler_temporal.transform(test_data[temporal_features])
    X_protocol_test = scaler_protocol.transform(test_data[protocol_features])

    # Reconstruct the input data
    reconstructed = autoencoder.predict([X_packet_test, X_temporal_test, X_protocol_test])

    # Calculate reconstruction error for each modality
    packet_mse = mean_squared_error(X_packet_test, reconstructed[0])
    temporal_mse = mean_squared_error(X_temporal_test, reconstructed[1])
    protocol_mse = mean_squared_error(X_protocol_test, reconstructed[2])

    print("Reconstruction Mean Squared Errors:")
    print(f"Packet Features MSE: {packet_mse}")
    print(f"Temporal Features MSE: {temporal_mse}")
    print(f"Protocol Features MSE: {protocol_mse}")

    # Visualize reconstruction for a few samples
    def plot_reconstruction(original, reconstructed, feature_names, title):
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1)
        plt.title(f'{title} - Original')
        plt.bar(feature_names, original[0])
        plt.xticks(rotation=45, ha='right')
        
        plt.subplot(1, 2, 2)
        plt.title(f'{title} - Reconstructed')
        plt.bar(feature_names, reconstructed[0])
        plt.xticks(rotation=45, ha='right')
        
        plt.tight_layout()
        plt.show()
        plt.close()

    # Plot reconstructions for the first few samples
    plot_reconstruction(
        [X_packet_test[0]], 
        [reconstructed[0][0]], 
        packet_features, 
        "Packet Features"
    )

    plot_reconstruction(
        [X_temporal_test[0]], 
        [reconstructed[1][0]], 
        temporal_features, 
        "Temporal Features"
    )

    # Optional: Visualize latent space representation
    from sklearn.manifold import TSNE
    
    # Extract latent space representations
    encoder = Model(
        inputs=autoencoder.inputs, 
        outputs=autoencoder.get_layer('latent_space').output
    )
    latent_representations = encoder.predict([X_packet_test, X_temporal_test, X_protocol_test])

    # Use t-SNE for dimensionality reduction
    tsne = TSNE(n_components=2, random_state=42)
    latent_2d = tsne.fit_transform(latent_representations)

    plt.figure(figsize=(10, 8))
    plt.scatter(latent_2d[:, 0], latent_2d[:, 1], alpha=0.7)
    plt.title('Latent Space Visualization')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel('t-SNE Dimension 2')
    plt.tight_layout()
    plt.show()
    plt.close()

    print("Testing complete. Reconstruction and visualization plots saved.")

# Example usage
if __name__ == "__main__":
    test_multimodal_autoencoder('test_set.csv')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Reconstruction Mean Squared Errors:
# Packet Features MSE: 26.55057791869707
# Temporal Features MSE: 61.261962098183474
# Protocol Features MSE: 15058.949244256164
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# Testing complete. Reconstruction and visualization plots saved.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import joblib

# Scikit-learn imports for classification and evaluation
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix, 
    classification_report,
    ConfusionMatrixDisplay
)

def extract_latent_representations(model_path, data_path, feature_groups):
    """
    Extract latent space representations from the trained autoencoder
    
    Parameters:
    - model_path: Path to the saved autoencoder model
    - data_path: Path to the input data CSV
    - feature_groups: Dictionary of feature groups
    
    Returns:
    - Latent space representations
    - Corresponding labels
    """
    # Load the model
    autoencoder = load_model(model_path, custom_objects={'MeanSquaredError': None})
    
    # Load scalers
    scaler_packet = joblib.load('packet_scaler.pkl')
    scaler_temporal = joblib.load('temporal_scaler.pkl')
    scaler_protocol = joblib.load('protocol_scaler.pkl')
    
    # Load data
    data = pd.read_csv(data_path)
    
    # Separate features
    X_packet = scaler_packet.transform(data[feature_groups['packet_features']])
    X_temporal = scaler_temporal.transform(data[feature_groups['temporal_features']])
    X_protocol = scaler_protocol.transform(data[feature_groups['protocol_features']])
    
    # Extract latent space representations
    encoder = Model(
        inputs=autoencoder.inputs, 
        outputs=autoencoder.get_layer('latent_space').output
    )
    latent_representations = encoder.predict([X_packet, X_temporal, X_protocol])
    
    # Extract labels (assuming the last column is the class label)
    y = data.iloc[:, -1]
    
    return latent_representations, y

def train_random_forest_on_latent_space(latent_reps, labels):
    """
    Train Random Forest Classifier on latent space representations
    
    Parameters:
    - latent_reps: Latent space representations
    - labels: Corresponding class labels
    
    Returns:
    - Trained Random Forest Classifier
    - Train and test sets
    """
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(
        latent_reps, labels, test_size=0.2, random_state=42
    )
    
    # Train Random Forest Classifier
    rf_classifier = RandomForestClassifier(
        n_estimators=100, 
        random_state=42, 
        n_jobs=-1
    )
    rf_classifier.fit(X_train, y_train)
    
    return rf_classifier, (X_train, X_test, y_train, y_test)

def evaluate_classification_performance(classifier, X_test, y_test):
    """
    Evaluate the performance of the Random Forest Classifier
    
    Parameters:
    - classifier: Trained Random Forest Classifier
    - X_test: Test features
    - y_test: Test labels
    
    Returns:
    - Dictionary of performance metrics
    """
    # Predict on test set
    y_pred = classifier.predict(X_test)
    
    # Calculate metrics
    metrics = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision (Weighted)': precision_score(y_test, y_pred, average='weighted'),
        'Recall (Weighted)': recall_score(y_test, y_pred, average='weighted'),
        'F1 Score (Weighted)': f1_score(y_test, y_pred, average='weighted')
    }
    
    # Print metrics
    print("\nClassification Performance Metrics:")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")
    
    # Print detailed classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot Confusion Matrix
    plt.figure(figsize=(10, 8))
    ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap='Blues', values_format='d')
    plt.title('Confusion Matrix for Latent Space Classification')
    plt.tight_layout()
    plt.show()
    plt.close()
    
    return metrics

def main():
    # Define feature groups (adjust according to your dataset)
    feature_groups = {
         'packet_features' : ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size'],

   
         'temporal_features' : ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur'],

         'protocol_features' : ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']
    }
    
    # Extract latent representations
    latent_representations, labels = extract_latent_representations(
        'multimodal_network_autoencoder.h5', 
        'Processed.csv',  # Your input dataset
        feature_groups
    )
    
    # Train Random Forest on latent space
    rf_classifier, (X_train, X_test, y_train, y_test) = train_random_forest_on_latent_space(
        latent_representations, labels
    )
    
    # Evaluate classification performance
    performance_metrics = evaluate_classification_performance(
        rf_classifier, X_test, y_test
    )
    
    # Optional: Feature importance in the latent space
    plt.figure(figsize=(10, 6))
    feature_importance = rf_classifier.feature_importances_
    plt.bar(range(len(feature_importance)), feature_importance)
    plt.title('Feature Importance in Latent Space')
    plt.xlabel('Latent Dimension')
    plt.ylabel('Importance')
    plt.tight_layout()
    plt.show()
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Classification Performance Metrics:
# Accuracy: 0.6356
# Precision (Weighted): 0.6327
# Recall (Weighted): 0.6356
# F1 Score (Weighted): 0.6276
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25         4
#            1       0.62      0.50      0.56        10
#            2       0.82      0.88      0.85        32
#            3       0.42      0.38      0.40        13
#            4       0.83      0.83      0.83        30
#            5       0.59      0.72      0.65        40
#            6       0.43      0.67      0.52         9
#            7       0.43      0.33      0.38         9
#            8       0.50      0.50      0.50         8
#            9       0.57      0.29      0.38        14
#           10       0.50      0.38      0.43        16
#           11       0.67      0.64      0.65        28
#           12       0.60      0.50      0.55         6
#           13       0.68      0.76      0.72        17
#
#     accuracy                           0.64       236
#    macro avg       0.57      0.55      0.55       236
# weighted avg       0.63      0.64      0.63       236
